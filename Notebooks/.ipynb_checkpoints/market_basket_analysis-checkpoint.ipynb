# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
df = pd.read_csv("../data/Groceries_dataset.csv")

df.head()
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk

# %%
te = TransactionEncoder()

te_array = te.fit(transactions).transform(transactions)

basket = pd.DataFrame(te_array, columns=te.columns_)

basket.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 te = TransactionEncoder()
#       2
# ----> 3 te_array = te.fit(transactions).transform(transactions)
#       4
#       5 basket = pd.DataFrame(te_array, columns=te.columns_)
#       6
#
# NameError: name 'transactions' is not defined

# %%
frequent_itemsets = apriori(
    basket,
    min_support=0.02,
    use_colnames=True
)

frequent_itemsets.head()
# Out:
#    support             itemsets
# 0     0.25    frozenset({Beer})
# 1     0.50   frozenset({Bread})
# 2     0.50  frozenset({Butter})
# 3     0.25   frozenset({Chips})
# 4     0.25    frozenset({Eggs})

# %%
rules = association_rules(
    frequent_itemsets,
    metric="lift",
    min_threshold=1
)

rules.head()
# Out:
#            antecedents          consequents  antecedent support  \
# 0   frozenset({Chips})    frozenset({Beer})                0.25
# 1    frozenset({Beer})   frozenset({Chips})                0.25
# 2  frozenset({Butter})   frozenset({Bread})                0.50
# 3   frozenset({Bread})  frozenset({Butter})                0.50
# 4    frozenset({Milk})   frozenset({Bread})                0.50
#
#    consequent support  support  confidence  lift  representativity  leverage  \
# 0                0.25     0.25         1.0   4.0               1.0    0.1875
# 1                0.25     0.25         1.0   4.0               1.0    0.1875
# 2                0.50     0.50         1.0   2.0               1.0    0.2500
# 3                0.50     0.50         1.0   2.0               1.0    0.2500
# 4                0.50     0.25         0.5   1.0               1.0    0.0000
#
#    conviction  zhangs_metric   jaccard  certainty  kulczynski
# ...

# %%
strong_rules = rules[
    (rules['confidence'] > 0.5) &
    (rules['lift'] > 1)
]

strong_rules
# Out:
#                   antecedents          consequents  antecedent support  \
# 0          frozenset({Chips})    frozenset({Beer})                0.25
# 1           frozenset({Beer})   frozenset({Chips})                0.25
# 2         frozenset({Butter})   frozenset({Bread})                0.50
# 3          frozenset({Bread})  frozenset({Butter})                0.50
# 9           frozenset({Eggs})    frozenset({Milk})                0.25
# 10  frozenset({Milk, Butter})   frozenset({Bread})                0.25
# 11   frozenset({Milk, Bread})  frozenset({Butter})                0.25
#
#     consequent support  support  confidence  lift  representativity  leverage  \
# 0                 0.25     0.25         1.0   4.0               1.0    0.1875
# 1                 0.25     0.25         1.0   4.0               1.0    0.1875
# 2                 0.50     0.50         1.0   2.0               1.0    0.2500
# 3                 0.50     0.50         1.0   2.0               1.0    0.2500
# ...

# %%
top_items = frequent_itemsets.sort_values(
    by='support',
    ascending=False
)

plt.figure(figsize=(10,5))

plt.bar(
    top_items['itemsets'].astype(str).head(10),
    top_items['support'].head(10)
)

plt.xticks(rotation=90)

plt.title("Top Frequent Itemsets")

plt.show()

# %%
top_items = frequent_itemsets.sort_values(
    by='support',
    ascending=False
)

plt.figure(figsize=(10,5))

plt.bar(
    top_items['itemsets'].astype(str).head(10),
    top_items['support'].head(10)
)

plt.xticks(rotation=90)

plt.title("Top Frequent Itemsets")

plt.show()

# %%
plt.show()

# %%
plt.savefig("../images/top_items.png")

# %% [markdown]
# 1. Bread and Butter are frequently purchased together.
#
# 2. Milk and Eggs show strong association.
#
# 3. Beer and Chips combinations indicate snack behavior.
#
# 4. Products with high lift values should be placed nearby.
